# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenMartin/Lets_Grow_More/blob/main/Iris%20Classification%20using%20Decision%20Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a =pd.read_csv("/content/drive/MyDrive/projects/Iris (1).csv")

# %%
a
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
a.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
x =a.drop(columns=['Species'])
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
y=a[['Species']]
y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size =0.2,train_size =0.8)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 5)
# (30, 5)
# (120, 1)
# (30, 1)

# %%
x_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 26    27            5.0           3.4            1.6           0.4
# 64    65            5.6           2.9            3.6           1.3
# 59    60            5.2           2.7            3.9           1.4
# 124  125            6.7           3.3            5.7           2.1
# 145  146            6.7           3.0            5.2           2.3
# 2      3            4.7           3.2            1.3           0.2
# 43    44            5.0           3.5            1.6           0.6
# 123  124            6.3           2.7            4.9           1.8
# 33    34            5.5           4.2            1.4           0.2
# 80    81            5.5           2.4            3.8           1.1
# 97    98            6.2           2.9            4.3           1.3
# 147  148            6.5           3.0            5.2           2.0
# 48    49            5.3           3.7            1.5           0.2
# ...

# %%
x_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 113  114            5.7           2.5            5.0           2.0
# 102  103            7.1           3.0            5.9           2.1
# 32    33            5.2           4.1            1.5           0.1
# 65    66            6.7           3.1            4.4           1.4
# 108  109            6.7           2.5            5.8           1.8
# ..   ...            ...           ...            ...           ...
# 79    80            5.7           2.6            3.5           1.0
# 6      7            4.6           3.4            1.4           0.3
# 101  102            5.8           2.7            5.1           1.9
# 120  121            6.9           3.2            5.7           2.3
# 55    56            5.7           2.8            4.5           1.3
#
# [120 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()
d.fit(x_train,y_train)
L=d.predict(x_test)
acc=d.score(x_test,y_test)
print(acc)
# Out:
# 1.0

# %%
from matplotlib import pyplot as plt 
from sklearn import tree

# %%
tree.plot_tree(d);

# %%
f=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
t=['setosa', 'versicolor', 'virginica']
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(d, 
                   feature_names=f,  
                   class_names=t,
                   filled=True)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (20,15))
plot = tree.plot_tree(d, feature_names = x.columns, filled = True,fontsize = 20)
